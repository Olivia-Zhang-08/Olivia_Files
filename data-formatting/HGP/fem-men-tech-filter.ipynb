# %% [markdown]
# # Filtering fem/men tech companies based on keywords (U.S.)

# %%
# import pandas and numpy libraries
import pandas as pd
import numpy as np
import csv

# read in the trimmed database (U.S., no target or target ID duplicates, added fem/men tech column) as a dataframe
fulldf = pd.read_csv('fem_men_tech_db.csv')
fulldf = fulldf.loc[:, ~fulldf.columns.str.contains('^Unnamed')]
fulldf = fulldf.replace(np.nan, '', regex = True)
df = fulldf.copy()
df.head(10)
# Out:
#                        Target AnnounceDate CloseDate Fem/Men  \
# 0                 Medigistics      1/21/14   1/21/14
# 1                   Relatient      1/21/14   1/21/14
# 2  API Healthcare Corporation      1/21/14   2/13/14
# 3                       Kareo      1/21/14   1/21/14
# 4           Change Collective      1/21/14
# 5              Quantum Health      1/22/14   1/22/14
# 6                      MDLive      1/22/14   1/22/14
# 7                   Eyelation      1/22/14   1/22/14
# 8                    Daymarck      1/23/14
# 9                      Fitmob      1/23/14   1/23/14
#
#                       Sector  \
# 0
# 1     Patient Communications
# 2  Infrastructure Technology
# 3                     PM/EMR
# 4              Provider - NC
# 5                    Content
# 6                    Telemed
# 7                   Employer
# 8
# 9
#
#                                    TargetDescription
# 0  Provides multi-specialty medical billing and a...
# 1  Provider of an online patient engagement platf...
# 2  Provides healthcare specific workforce managem...
# 3  Provides cloud-based medical office software a...
# 4  Platform offers videos, articles, and podcasts...
# 5  Operates as a consumer navigation and care coo...
# 6  A network of Board certified physicians and li...
# 7  A provider of kiosks and web technology to pro...
# 8  Provides home health care coding and auditing ...
# 9  Owns and operates an online community for fitn...

# %%
# find number of companies
count = len(df['TargetDescription'])
# change all descriptions to lowercase to match keywords
for i in range(count):
    df.at[i, 'TargetDescription'] = df['TargetDescription'][i].lower()
df.head(10)
# Out:
#                        Target AnnounceDate CloseDate Fem/Men  \
# 0                 Medigistics      1/21/14   1/21/14
# 1                   Relatient      1/21/14   1/21/14
# 2  API Healthcare Corporation      1/21/14   2/13/14
# 3                       Kareo      1/21/14   1/21/14
# 4           Change Collective      1/21/14
# 5              Quantum Health      1/22/14   1/22/14
# 6                      MDLive      1/22/14   1/22/14
# 7                   Eyelation      1/22/14   1/22/14
# 8                    Daymarck      1/23/14
# 9                      Fitmob      1/23/14   1/23/14
#
#                       Sector  \
# 0
# 1     Patient Communications
# 2  Infrastructure Technology
# 3                     PM/EMR
# 4              Provider - NC
# 5                    Content
# 6                    Telemed
# 7                   Employer
# 8
# 9
#
#                                    TargetDescription
# 0  provides multi-specialty medical billing and a...
# 1  provider of an online patient engagement platf...
# 2  provides healthcare specific workforce managem...
# 3  provides cloud-based medical office software a...
# 4  platform offers videos, articles, and podcasts...
# 5  operates as a consumer navigation and care coo...
# 6  a network of board certified physicians and li...
# 7  a provider of kiosks and web technology to pro...
# 8  provides home health care coding and auditing ...
# 9  owns and operates an online community for fitn...

# %%
femKeys = list(np.genfromtxt('fem-keys.txt',dtype='str'))
menKeys = list(np.genfromtxt('men-keys.txt',dtype='str', delimiter = '\n'))
for i in range(len(menKeys)):
    if menKeys[i] == 'men' or menKeys[i] == 'hair':
        menKeys[i] = ' ' + menKeys[i] + ' '
bothKeys = list(np.genfromtxt('both-keys.txt', dtype='str'))
print('Only fem: ',femKeys)
print('Only men: ', menKeys)
print('Can be both: ', bothKeys)
# Out:
# Only fem:  ['women', 'woman', 'feminine', 'female', 'femtech', 'pregnancy', 'birth', 'fetus', 'vitro', 'maternity', 'maternal', 'egg', 'breast', 'feeding', 'embryo', 'ovulation', 'menstrual', 'menstruation', 'tampon', 'contraceptive', 'contraception']
# Only men:  [' men ', ' hair ', 'male', 'sperm', 'erectile', 'paternal', 'paternity']
# Can be both:  ['fertile', 'fertility', 'baby', 'babies', 'std', 'sex', 'sexual']

# %%
# label femtech companies
for i in range(count): 
    for j in femKeys:
        if j in df['TargetDescription'][i]:
            df.at[i, 'Fem/Men'] = 'F'
df.tail(10)
# Out:
#                       Target AnnounceDate CloseDate Fem/Men  \
# 3255             Ride Health       1/7/20    1/7/20
# 3256          Ripple Science       1/7/20    1/7/20
# 3257              MD-Reports       1/7/20    1/7/20
# 3258  GHR RevCycle Workforce     12/31/19  12/31/19
# 3259               WiserCare     11/22/19  11/22/19
# 3260         Advantia Health       1/8/20    1/8/20       F
# 3261                    Yaro       1/8/20    1/8/20
# 3262             RecoveryOne     12/17/19  12/17/19
# 3263                    Humm     12/19/19  12/19/19
# 3264               Blue Mesa       1/9/20    1/9/20
#
#                            Sector  \
# 3255                        Other
# 3256    Clinical Trial Management
# 3257                       PM/EMR
# 3258                 RCM Services
# 3259             Decision Support
# 3260                      Telemed
# 3261          Benefits Management
# 3262  Population Health - Chronic
# 3263                      Fitness
# 3264              Care Management
#
#                                       TargetDescription
# 3255  provider and coordinator of transportation for...
# 3256  provider of saas software that is designed to ...
# 3257  provider of electronic medical record (emr), p...
# 3258  the company provides coding, clinical document...
# 3259  developer of an interactive patient decision s...
# 3260  operator of an integrated healthcare delivery ...
# 3261  provider of benefits navigation and care guida...
# 3262  developer of a medical software designed to tr...
# 3263  developer of brain stimulating wearable patch....
# 3264  developer of diabetes prevention digital platf...

# %%
# extract fem-only companies to new dataframe
dfFem = df.loc[df['Fem/Men'] == 'F']
countFem = len(dfFem)
print('Number of fem-only companies in database: ', countFem)
dfFem.head(10)
# Out:
# Number of fem-only companies in database:  43
#                          Target AnnounceDate CloseDate Fem/Men    Sector  \
# 203                     Counsyl       5/8/14    5/8/14       F  Genomics
# 227   BabyWatch (aka Bellabeat)      5/23/14   5/23/14       F   Fitness
# 393                     Kindara      8/31/14   8/31/14       F   Fitness
# 396               WiserTogether       9/2/14                 F
# 538                    Celmatix      12/3/14   7/17/15       F
# 724                Maven Clinic       6/5/14    4/9/15       F   Telemed
# 838           Wildflower Health      6/25/15   6/25/15       F   Telemed
# 961                      Joylux      9/22/15   9/22/15       F
# 1142                Mammosphere      1/26/16    1/1/16       F
# 1498                  Bloomlife      8/17/16   8/17/16       F   Fitness
#
#                                       TargetDescription
# 203   operates as a medical genomics company. the co...
# 227   developer of heath tracking devices designed t...
# 393   developer of a fertility tracking application ...
# 396   provides an interactive platform for health ca...
# 538   a personalized medicine company that focuses o...
# 724         provides a telemedicine platform for women.
# 838   operates an online health engagement platform ...
# 961   offers led-based therapeutic products, includi...
# 1142  provides a medical image sharing network that ...
# 1498          developer of wearable pregnancy monitors.

# %%
dfFem.index
# Out:
# Int64Index([ 203,  227,  393,  396,  538,  724,  838,  961, 1142, 1498, 1541,
#             1562, 1699, 1705, 1898, 1967, 1974, 2031, 2122, 2231, 2258, 2282,
#             2358, 2412, 2448, 2463, 2466, 2508, 2615, 2632, 2799, 2816, 2835,
#             2837, 2841, 2856, 2862, 2976, 3034, 3072, 3087, 3142, 3260],
#            dtype='int64')

# %%
# export fem data to new csv
dfFem.to_csv('filtered_fem_db.csv')

# %%
# do same for men-only companies

# %%
# label them with M
for i in range(count): 
    for j in menKeys:
        if j in df['TargetDescription'][i] and df['Fem/Men'][i] == '':
            df.at[i, 'Fem/Men'] = 'M'

# %%
# extract all femtech-labeled companies to new dataframe
dfMen = df.loc[df['Fem/Men'] == 'M']
countMen = len(dfMen)
print('Number of mentech companies in database: ', countMen)
dfMen
# Out:
# Number of mentech companies in database:  4
#                                 Target AnnounceDate CloseDate Fem/Men  \
# 2078  Roman Health Medical (dba Roman)     10/31/17  10/31/17       M
# 2290                              Hims       3/2/18    3/2/18       M
# 2635                     ThirtyMadison     10/16/18  10/16/18       M
# 3037                              Dadi       8/8/19    8/8/19       M
#
#        Sector                                  TargetDescription
# 2078  Telemed  a cloud pharmacy for erectile dysfunction, han...
# 2290  Fitness  provider of wellness products intended to offe...
# 2635  Telemed  an online virtual men's health platform focuse...
# 3037  Fitness  provider of health services intended for male ...

# %%
# export to new csv
dfMen.to_csv('filtered_men_db.csv')

# %%
# do same for potentially both gender companies

# %%
# label with B
for i in range(count): 
    for j in bothKeys:
        if j in df['TargetDescription'][i] and df['Fem/Men'][i] == '':
            df.at[i, 'Fem/Men'] = 'B'

# %%
# extract to new dataframe
dfBoth = df.loc[df['Fem/Men'] == 'B']
countBoth = len(dfBoth)
print('Number of companies likely for general parenting in database: ', countBoth)
dfBoth
# Out:
# Number of companies likely for general parenting in database:  12
#                               Target AnnounceDate CloseDate Fem/Men  \
# 169                  Owlet Baby Care      4/22/14   4/22/14       B
# 647                       Sproutling      2/16/15                 B
# 685           FertilityAuthority.com      3/12/15   3/12/15       B
# 999                       Hatch Baby     10/15/15  10/15/15       B
# 1462                         Progyny      6/15/16    5/2/17       B
# 1596                       Renew.com      11/4/16  11/17/16       B
# 1891  Wearless Tech (dba Cocoon Cam)      6/28/17   6/28/17       B
# 2004                Carrot Fertility      9/14/17   9/14/17       B
# 2529                       myLAB Box      8/16/18   8/16/18       B
# 2623                         Pr3vent       8/1/18    8/1/18       B
# 3050                      MedAnswers      8/13/19   8/13/19       B
# 3082                      Smart Beat      8/30/19   8/30/19       B
#
#                    Sector                                  TargetDescription
# 169               Fitness  maker of a baby monitor that includes heart ra...
# 647                        offers sensor system designed to wrap around a...
# 685                                       operates as a fertility web portal
# 999               Fitness  developer of smart wireless parenting devices ...
# 1462  Benefits Management  provider of fertility benefits management serv...
# 1596                       operates a cloud-based senior benefits platfor...
# 1891              Fitness  developer of an intelligent baby breathing vid...
# 2004  Benefits Management  provider of a modern fertility platform intend...
# 2529              Fitness  provider of at-home std testing kits intended ...
# 2623     Decision Support  provider of an artificial intelligence based s...
# 3050              Telemed  developer of a healthcare application designed...
# 3082              Fitness  offers a video baby monitor with breath detect...

# %%
# export to new csv
dfBoth.to_csv('filtered_both_db.csv')

# %%
for i in range(len(df)):
    if df['Fem/Men'][i] == "":
        df = df.drop([i], axis = 0)
df.head(10)
df.to_csv('filtered_all_db.csv')
